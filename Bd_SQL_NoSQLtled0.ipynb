# %% [markdown]
# <a href="https://colab.research.google.com/github/ivancharris/FirstRepo/blob/main/Bd_SQL_NoSQLtled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Extracion de datos desde MySQL

# %%
# !pip install pymysql
# !pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.6/603.6 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.0/300.0 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.6 MB/s eta 0:00:00
# ...

# %%
from sqlalchemy import create_engine, text
import pandas as pd
import pymysql

# %%
engine = create_engine("mysql+pymysql://ivanCharris:123456789@34.125.228.77/retail_db")
conn = engine.connect()

# %%
orders_df= pd.read_sql_query(text('SELECT * FROM orders'), con= conn)
orders_df
# Out:
#        order_id order_date  order_customer_id     order_status
# 0             1 2013-07-25              11599           CLOSED
# 1             2 2013-07-25                256  PENDING_PAYMENT
# 2             3 2013-07-25              12111         COMPLETE
# 3             4 2013-07-25               8827           CLOSED
# 4             5 2013-07-25              11318         COMPLETE
# ...         ...        ...                ...              ...
# 68878     68879 2014-07-09                778         COMPLETE
# 68879     68880 2014-07-13               1117         COMPLETE
# 68880     68881 2014-07-19               2518  PENDING_PAYMENT
# 68881     68882 2014-07-22              10000          ON_HOLD
# 68882     68883 2014-07-23               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
from pymongo import MongoClient

# %%
#crear conexion
cliente = MongoClient('mongodb+srv://ivancharrisc:95gx4jdkX7Klr1aU@cluster0.3wlpil8.mongodb.net/?retryWrites=true&w=majority')
cliente
# Out:
# MongoClient(host=['ac-cazdid3-shard-00-00.3wlpil8.mongodb.net:27017', 'ac-cazdid3-shard-00-02.3wlpil8.mongodb.net:27017', 'ac-cazdid3-shard-00-01.3wlpil8.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-253458-shard-0', tls=True)

# %%
#seleccionar base de datos
db= cliente['retail_db']
db
# Out:
# Database(MongoClient(host=['ac-cazdid3-shard-00-00.3wlpil8.mongodb.net:27017', 'ac-cazdid3-shard-00-02.3wlpil8.mongodb.net:27017', 'ac-cazdid3-shard-00-01.3wlpil8.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-253458-shard-0', tls=True), 'retail_db')

# %%
#seleccionar coleccion
collection = db['departments']

documentos = list(collection.find())

# %%
# Convertir la lista de documentos en un DataFrame

df_departments = pd.DataFrame(documentos)
# Out:
#                         _id  department_id department_name
# 0  64b9bc1092a987e06283b7ae              2         Fitness
# 1  64b9bc1092a987e06283b7af              3        Footwear
# 2  64b9bc1092a987e06283b7b0              4         Apparel
# 3  64b9bc1092a987e06283b7b1              5            Golf
# 4  64b9bc1092a987e06283b7b2              6        Outdoors
# 5  64b9bc1092a987e06283b7b3              7        Fan Shop

# %%
#seleccionar coleccion
collection = db['orders']

documentos = list(collection.find())

df_order = pd.DataFrame(documentos)

df_order = df_order.drop(columns=['_id'])
df_order.head()
# Out:
#    order_id order_date  order_customer_id     order_status
# 0         1 2013-07-25              11599           CLOSED
# 1         2 2013-07-25                256  PENDING_PAYMENT
# 2         3 2013-07-25              12111         COMPLETE
# 3         4 2013-07-25               8827           CLOSED
# 4         5 2013-07-25              11318         COMPLETE
